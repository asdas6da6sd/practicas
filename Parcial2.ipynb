# %% [markdown]
# <a href="https://colab.research.google.com/github/asdas6da6sd/practicas/blob/master/Parcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
path ='/content/drive/My Drive/prodim/'
os.chdir(path)
# !pwd
# %matplotlib inline
# Out:
# /content/drive/My Drive/prodim

# %%
def display3(a, b,c,title1 = "Original", title2 = "Edited", title3 = "Edited"):
    plt.figure(figsize=(20,20))
    plt.subplot(131), plt.imshow(a,cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132), plt.imshow(b,cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(133), plt.imshow(c,cmap='gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def display2(a, b,title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(20,20))
    plt.subplot(121), plt.imshow(a,cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b,cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
img = cv2.imread('flores.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante,flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
fils,cols = img.shape
centfils,centcols = fils/2,cols/2



r=60
r2=50
center = [centfils,centcols]
x, y = np.ogrid[:fils,:cols]
x2,y2 = np.ogrid[:fils,:cols]

mask= np.ones((fils,cols,2),np.uint8)
mask_area = (x-center[0]) ** 2 + (y-center[1]) ** 2 <= r*r
mask_area2 = (x2-center[0]) ** 2 + (y2-center[1]) ** 2 <= r2*r2
mask[mask_area]=0
mask[mask_area2]=1



display3(img,magnitude_spectrum,fshift_mask_mag, "image","spectrum","notch")

# %%
img = cv2.imread('flores.jpg',0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante,flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
fils,cols = img.shape
centfils,centcols = fils/2,cols/2



r=60
r2=50
center = [centfils,centcols]
x, y = np.ogrid[:fils,:cols]
x2,y2 = np.ogrid[:fils,:cols]

mask= np.zeros((fils,cols,2),np.uint8)
mask_area = (x-center[0]) ** 2 + (y-center[1]) ** 2 <= r*r
mask_area2 = (x2-center[0]) ** 2 + (y2-center[1]) ** 2 <= r2*r2
mask[mask_area]=1
mask[mask_area2]=0

fshift = dft_shift*mask
fshift_mask_mag1 = 20*np.log(cv2.magnitude(fshift[:,:,0],fshift[:,:,1]))

display3(img,magnitude_spectrum,fshift_mask_mag1, "image","spectrum","passband")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log

# %%
img = cv2.imread("saltlgle.png",0)
median = cv2.medianBlur(img,5)
median1 = cv2.medianBlur(median,5)

display2(img,median1)


img_flotante = np.float32(median1)
dft = cv2.dft(img_flotante,flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
fils,cols = img.shape
centfils,centcols = fils/2,cols/2

##crear mascara centro en unos resto en ceros

mask= np.ones((fils,cols,2),np.uint8)
r=10
center = [centfils,centcols]
x, y = np.ogrid[:fils,:cols]

mask= np.ones((fils,cols,2),np.uint8)
mask_area = (x-center[0]) ** 2 + (y-center[1]) ** 2 <= r*r
mask[mask_area]=0
##mask[np.int32(centfils)-9 : np.int32(centfils)+9,np.int32(centcols)-9 : np.int32(centcols)+9]=0

##aplicar mascara y obtener inversa 

fshift = dft_shift*mask
fshift_mask_mag = 20*np.log(cv2.magnitude(fshift[:,:,0],fshift[:,:,1]))
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
display3(img_back,fshift_mask_mag,magnitude_spectrum, "Filtered image","spectrum with mask","spectrum")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log

# %%
img = cv2.imread("dama.png",0)
median = cv2.medianBlur(img,3)
median1 = cv2.medianBlur(median,5)
display2(img,median1)
