# %% [markdown]
# <a href="https://colab.research.google.com/github/asdas6da6sd/practicas/blob/master/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
path ='/content/drive/My Drive/prodim/'
os.chdir(path)
# !pwd
# %matplotlib inline
# Out:
# /content/drive/My Drive/prodim

# %%
def displayGray2(a, b,title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(121), plt.imshow(a,cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b,cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def fraccionamiento(img,minr=10,maxr=60,minr1=10,maxr1=60):
    img=cv2.imread(img,0)
    rows,columns = img.shape
    img2 =np.zeros((rows,columns),dtype =np.uint8)
    
    a= minr
    b= maxr
    c= minr1
    d= maxr1
    
    for x in range (0,rows):
        for y in range (0,columns):
          r = img[x][y]
          if (a <= r and b >=r) or (c <= r and d >=r):
               img2[x][y] = 255
          else:
                img2[x][y] = 0
    displayGray2(img,img2)
    return
fraccionamiento('pastel.png',223,238,50,58)

# %%
def fraccionamiento(img3,minr=10,maxr=60,minr1=10,maxr1=60):
    img3=cv2.imread(img3,0)
    rows,columns = img3.shape
    img4 =np.zeros((rows,columns),dtype =np.uint8)
    
    a= minr
    b= maxr
    c= minr1
    d= maxr1
    
    for x in range (0,rows):
        for y in range (0,columns):
          r = img3[x][y]
          if (a <= r and b >=r) or (c <= r and d >=r):
               img4[x][y] = 255
          else:
                img4[x][y] = 0
    displayGray2(img3,img4)
    return
fraccionamiento('dulces2.jpg',210,255,10,30)
